# %% [markdown]
# # Exercise 6.1: Ewald Sphere and Bragg Condition
#
# ## Difficulty: Beginner
#
# In this exercise, you will practice:
# 1. Constructing Ewald spheres for different electron wavelengths
# 2. Identifying reciprocal lattice points near the Ewald sphere
# 3. Calculating excitation errors
# 4. Understanding how crystal tilt affects the diffraction pattern
#
# ---
#
# ## Problem 1: Ewald Sphere for Different Energies
#
# **Task**: Construct Ewald spheres for electrons with kinetic energies E = 50, 100, and 200 keV.
#
# For each energy:
# - Calculate the de Broglie wavelength: $\lambda = h / \sqrt{2 m_e E (1 + E/(2m_ec^2))}$
# - Determine the Ewald sphere radius: $k = 1/\lambda$
# - Plot the Ewald sphere and reciprocal lattice for a cubic crystal with $a = 3.0$ Å
#
# **Questions**:
# 1. How does the Ewald sphere radius change with energy?
# 2. For which energies can you excite the (200) reflection simultaneously with the (220) reflection?
# 3. What is the minimum energy needed to simultaneously excite (111), (200), and (220) reflections?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# YOUR CODE HERE
# 1. Define function to calculate wavelength from energy
# 2. Calculate k-radii for the three energies
# 3. Plot Ewald spheres and reciprocal lattice
# 4. Answer the questions

print("Problem 1: Ewald Sphere Construction")
print("="*50)

# %% [markdown]
# ## Problem 2: Excitation Error Mapping
#
# **Task**: For a Cu crystal (a = 3.615 Å) at 100 keV electron energy:
# - Calculate excitation error $s_g = \mathbf{g} \cdot \hat{\mathbf{k}}_i + |\mathbf{g}|^2/(2k)$ for all reflections with $|h|, |k|, |l| \leq 3$
# - Create a heatmap showing $s_g$ for different crystal tilt angles (from -10° to +10°)
# - Identify which tilts produce two-beam conditions (only one reflection near $s_g = 0$)
#
# **Questions**:
# 1. At what tilt angle is the (111) reflection at exact Bragg condition?
# 2. What is the range of $s_g$ values where a reflection is considered "excited" (weakly)
# 3. Which tilt angles produce the cleanest two-beam condition?

# %%
# YOUR CODE HERE
# 1. Generate all reciprocal lattice points for Cu
# 2. Calculate s_g for different tilts
# 3. Create heatmap(s) of excitation error
# 4. Identify two-beam conditions

print("Problem 2: Excitation Error Mapping")
print("="*50)

# %% [markdown]
# ## Problem 3: Reciprocal Lattice Resolution
#
# **Task**: For electrons with wavelength λ = 0.01 Å:
# - Calculate how many reciprocal lattice points fit within the Ewald sphere for $a = 2.5$ Å (BCC)
# - For a FCC crystal with the same lattice parameter, how many allowed reflections are there?
# - Plot the density of reciprocal lattice points vs wavelength
#
# **Questions**:
# 1. Why do high-energy (short wavelength) electrons produce multi-beam diffraction patterns?
# 2. How does the number of excited reflections scale with electron wavelength?
# 3. What is the advantage of using very high energy electrons in TEM?

# %%
# YOUR CODE HERE
# 1. Calculate number of reciprocal lattice points in Ewald sphere
# 2. Consider systematic absences (structure factor for FCC)
# 3. Plot density vs wavelength

print("Problem 3: Reciprocal Lattice Resolution")
print("="*50)

# %% [markdown]
# ## Challenge Problem: Bragg Condition for Off-Axis Tilt
#
# **Advanced Task**: A crystal is tilted in 2D (both x and y directions). For a cubic lattice with $a = 3.0$ Å:
# - Calculate the excitation error for the (220) reflection as a function of 2D tilt angle
# - Create a 2D map showing the Bragg condition contour
# - Determine the angular acceptance range ("Darwin width") for this reflection at 100 keV
#
# The Darwin width is approximately: $w \approx 2|\chi_g| / (2|s_g| \cos(\theta_B))$ where $\theta_B$ is the Bragg angle.

# %%
# YOUR CODE HERE
# 1. Calculate 2D tilt dependence of s_g
# 2. Plot Bragg condition contours
# 3. Calculate Darwin width (angular acceptance)

print("Challenge: 2D Tilt Bragg Condition")
print("="*50)

# %% [markdown]
# ## Self-Assessment Rubric
#
# | Concept | Mastery | Understanding | Needs Work |
# |---------|---------|---------------|-----------|
# | Ewald sphere geometry | Can explain and draw | Can use formula | Confused |
# | Reciprocal lattice | Can identify allowed reflections | Can plot | Unsure |
# | Excitation error | Can calculate and interpret | Understands concept | Unclear |
# | Bragg condition | Can find optimal tilt angles | Knows it's when s_g=0 | Confused |
# | Two-beam condition | Can identify and verify | Can recognize | Can't identify |
#
# ## References
# - Lecture 6.1: Dynamical Diffraction and Bloch Waves
# - Example 6.1: Ewald Sphere Construction (in code_examples/)
# - Spence & Zuo (1992): Chapter 2 on Reciprocal Lattice and Ewald Sphere
